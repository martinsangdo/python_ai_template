# %% [markdown]
# #test Langchain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()
llm.invoke("Hello, world!")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI()
# ----> 4 llm.invoke("Hello, world!")
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:368, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     356 @override
#     357 def invoke(
#     358     self,
#    (...)
#     363     **kwargs: Any,
#     364 ) -> BaseMessage:
#     365     config = ensure_config(config)
#     366     return cast(
#     367         "ChatGeneration",
# --> 368         self.generate_prompt(
#     369             [self._convert_input(input)],
#     370             stop=stop,
#     371             callbacks=config.get("callbacks"),
#     372             tags=config.get("tags"),
#     373             metadata=config.get("metadata"),
#     374             run_name=config.get("run_name"),
#     375             run_id=config.pop("run_id", None),
#     376             **kwargs,
#     377         ).generations[0][0],
#     378     ).message
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:937, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     928 @override
#     929 def generate_prompt(
#     930     self,
#    (...)
#     934     **kwargs: Any,
#     935 ) -> LLMResult:
#     936     prompt_messages = [p.to_messages() for p in prompts]
# --> 937     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:759, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     756 for i, m in enumerate(messages):
#     757     try:
#     758         results.append(
# --> 759             self._generate_with_cache(
#     760                 m,
#     761                 stop=stop,
#     762                 run_manager=run_managers[i] if run_managers else None,
#     763                 **kwargs,
#     764             )
#     765         )
#     766     except BaseException as e:
#     767         if run_managers:
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:1002, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1000     result = generate_from_stream(iter(chunks))
#    1001 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1002     result = self._generate(
#    1003         messages, stop=stop, run_manager=run_manager, **kwargs
#    1004     )
#    1005 else:
#    1006     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/langchain_openai/chat_models/base.py:991, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     989     generation_info = {"headers": dict(raw_response.headers)}
#     990 else:
# --> 991     response = self.client.create(**payload)
#     992 return self._create_chat_result(response, generation_info)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/resources/chat/completions/completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     886 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     887 def create(
#     888     self,
#    (...)
#     926     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     927 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     928     validate_response_format(response_format)
# --> 929     return self._post(
#     930         "/chat/completions",
#     931         body=maybe_transform(
#     932             {
#     933                 "messages": messages,
#     934                 "model": model,
#     935                 "audio": audio,
#     936                 "frequency_penalty": frequency_penalty,
#     937                 "function_call": function_call,
#     938                 "functions": functions,
#     939                 "logit_bias": logit_bias,
#     940                 "logprobs": logprobs,
#     941                 "max_completion_tokens": max_completion_tokens,
#     942                 "max_tokens": max_tokens,
#     943                 "metadata": metadata,
#     944                 "modalities": modalities,
#     945                 "n": n,
#     946                 "parallel_tool_calls": parallel_tool_calls,
#     947                 "prediction": prediction,
#     948                 "presence_penalty": presence_penalty,
#     949                 "reasoning_effort": reasoning_effort,
#     950                 "response_format": response_format,
#     951                 "seed": seed,
#     952                 "service_tier": service_tier,
#     953                 "stop": stop,
#     954                 "store": store,
#     955                 "stream": stream,
#     956                 "stream_options": stream_options,
#     957                 "temperature": temperature,
#     958                 "tool_choice": tool_choice,
#     959                 "tools": tools,
#     960                 "top_logprobs": top_logprobs,
#     961                 "top_p": top_p,
#     962                 "user": user,
#     963                 "web_search_options": web_search_options,
#     964             },
#     965             completion_create_params.CompletionCreateParamsStreaming
#     966             if stream
#     967             else completion_create_params.CompletionCreateParamsNonStreaming,
#     968         ),
#     969         options=make_request_options(
#     970             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971         ),
#     972         cast_to=ChatCompletion,
#     973         stream=stream or False,
#     974         stream_cls=Stream[ChatCompletionChunk],
#     975     )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)
#    1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1042, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1040 if remaining_retries > 0 and self._should_retry(err.response):
#    1041     err.response.close()
# -> 1042     return self._retry_request(
#    1043         input_options,
#    1044         cast_to,
#    1045         retries_taken=retries_taken,
#    1046         response_headers=err.response.headers,
#    1047         stream=stream,
#    1048         stream_cls=stream_cls,
#    1049     )
#    1051 # If the response is streamed then we need to explicitly read the response
#    1052 # to completion before attempting to access the response text.
#    1053 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1091, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1087 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1088 # different thread if necessary.
#    1089 time.sleep(timeout)
# -> 1091 return self._request(
#    1092     options=options,
#    1093     cast_to=cast_to,
#    1094     retries_taken=retries_taken + 1,
#    1095     stream=stream,
#    1096     stream_cls=stream_cls,
#    1097 )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1042, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1040 if remaining_retries > 0 and self._should_retry(err.response):
#    1041     err.response.close()
# -> 1042     return self._retry_request(
#    1043         input_options,
#    1044         cast_to,
#    1045         retries_taken=retries_taken,
#    1046         response_headers=err.response.headers,
#    1047         stream=stream,
#    1048         stream_cls=stream_cls,
#    1049     )
#    1051 # If the response is streamed then we need to explicitly read the response
#    1052 # to completion before attempting to access the response text.
#    1053 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1091, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1087 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1088 # different thread if necessary.
#    1089 time.sleep(timeout)
# -> 1091 return self._request(
#    1092     options=options,
#    1093     cast_to=cast_to,
#    1094     retries_taken=retries_taken + 1,
#    1095     stream=stream,
#    1096     stream_cls=stream_cls,
#    1097 )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054         err.response.read()
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)
#    1065     retries_taken=retries_taken,
#    1066 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-4.1",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 from openai import OpenAI
#       2 client = OpenAI()
# ----> 4 response = client.responses.create(
#       5     model="gpt-4.1",
#       6     input="Write a one-sentence bedtime story about a unicorn."
#       7 )
#       9 print(response.output_text)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/resources/responses/responses.py:661, in Responses.create(self, input, model, include, instructions, max_output_tokens, metadata, parallel_tool_calls, previous_response_id, reasoning, service_tier, store, stream, temperature, text, tool_choice, tools, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     631 @required_args(["input", "model"], ["input", "model", "stream"])
#     632 def create(
#     633     self,
#    (...)
#     659     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     660 ) -> Response | Stream[ResponseStreamEvent]:
# --> 661     return self._post(
#     662         "/responses",
#     663         body=maybe_transform(
#     664             {
#     665                 "input": input,
#     666                 "model": model,
#     667                 "include": include,
#     668                 "instructions": instructions,
#     669                 "max_output_tokens": max_output_tokens,
#     670                 "metadata": metadata,
#     671                 "parallel_tool_calls": parallel_tool_calls,
#     672                 "previous_response_id": previous_response_id,
#     673                 "reasoning": reasoning,
#     674                 "service_tier": service_tier,
#     675                 "store": store,
#     676                 "stream": stream,
#     677                 "temperature": temperature,
#     678                 "text": text,
#     679                 "tool_choice": tool_choice,
#     680                 "tools": tools,
#     681                 "top_p": top_p,
#     682                 "truncation": truncation,
#     683                 "user": user,
#     684             },
#     685             response_create_params.ResponseCreateParamsStreaming
#     686             if stream
#     687             else response_create_params.ResponseCreateParamsNonStreaming,
#     688         ),
#     689         options=make_request_options(
#     690             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     691         ),
#     692         cast_to=Response,
#     693         stream=stream or False,
#     694         stream_cls=Stream[ResponseStreamEvent],
#     695     )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)
#    1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1042, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1040 if remaining_retries > 0 and self._should_retry(err.response):
#    1041     err.response.close()
# -> 1042     return self._retry_request(
#    1043         input_options,
#    1044         cast_to,
#    1045         retries_taken=retries_taken,
#    1046         response_headers=err.response.headers,
#    1047         stream=stream,
#    1048         stream_cls=stream_cls,
#    1049     )
#    1051 # If the response is streamed then we need to explicitly read the response
#    1052 # to completion before attempting to access the response text.
#    1053 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1091, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1087 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1088 # different thread if necessary.
#    1089 time.sleep(timeout)
# -> 1091 return self._request(
#    1092     options=options,
#    1093     cast_to=cast_to,
#    1094     retries_taken=retries_taken + 1,
#    1095     stream=stream,
#    1096     stream_cls=stream_cls,
#    1097 )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1042, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1040 if remaining_retries > 0 and self._should_retry(err.response):
#    1041     err.response.close()
# -> 1042     return self._retry_request(
#    1043         input_options,
#    1044         cast_to,
#    1045         retries_taken=retries_taken,
#    1046         response_headers=err.response.headers,
#    1047         stream=stream,
#    1048         stream_cls=stream_cls,
#    1049     )
#    1051 # If the response is streamed then we need to explicitly read the response
#    1052 # to completion before attempting to access the response text.
#    1053 if not err.response.is_closed:
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1091, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1087 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1088 # different thread if necessary.
#    1089 time.sleep(timeout)
# -> 1091 return self._request(
#    1092     options=options,
#    1093     cast_to=cast_to,
#    1094     retries_taken=retries_taken + 1,
#    1095     stream=stream,
#    1096     stream_cls=stream_cls,
#    1097 )
#
# File ~/.pyenv/versions/3.9.10/lib/python3.9/site-packages/openai/_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054         err.response.read()
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)
#    1065     retries_taken=retries_taken,
#    1066 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
